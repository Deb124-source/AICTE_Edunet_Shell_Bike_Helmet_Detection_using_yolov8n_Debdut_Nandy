# %% [markdown]
# # **1. Check Graphics Card is running or not**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/ColabNotebooks/ObjectDetection/
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/ColabNotebooks/ObjectDetection
# AICTE_Edunet_Shell_Bike_Helmet_Detection_using_yolov8n_Debdut_Nandy-main.zip

# %%
# !nvidia-smi
# Out:
# Sat Nov 15 03:47:14 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # **2. Install Ultralytics**

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **3. Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #**4. Start Training of YOLOv8  with Custom Dataset**

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=/content/drive/MyDrive/Dataset/BikeHelmet/data.yaml epochs=10 imgsz=640 batch=16
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # **5. Output: Prediction based on input**

# %%
# !yolo detect predict model='/content/AICTE_Edunet_Shell_Bike_Helmet_Detection_using_yolov8n_Debdut_Nandy-main/runs/detect/train2/weights/best.pt' source='/content/6b1bdefb532196793dc1c223e1355013.jpg' save=True
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,608,150 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/6b1bdefb532196793dc1c223e1355013.jpg: 448x640 3 Without Helmets, 61.0ms
# Speed: 2.3ms preprocess, 61.0ms inference, 2.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/AICTE_Edunet_Shell_Bike_Helmet_Detection_using_yolov8n_Debdut_Nandy-main/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict model='/content/AICTE_Edunet_Shell_Bike_Helmet_Detection_using_yolov8n_Debdut_Nandy-main/runs/detect/train2/weights/best.pt' source='/content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4' save=True
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,608,150 parameters, 0 gradients, 164.8 GFLOPs
#
# video 1/1 (frame 1/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 2 With Helmets, 59.8ms
# video 1/1 (frame 2/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 (no detections), 39.6ms
# video 1/1 (frame 3/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 1 With Helmet, 38.6ms
# video 1/1 (frame 4/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 (no detections), 38.6ms
# video 1/1 (frame 5/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 (no detections), 38.6ms
# video 1/1 (frame 6/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 (no detections), 38.6ms
# video 1/1 (frame 7/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 1 With Helmet, 23.9ms
# ...
