# %% [markdown]
# # **Check Graphics Card is running or not**

# %%
# !nvidia-smi
# Out:
# Mon Nov  3 05:38:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# **Install Ultralytics**

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**Start Training of YOLO with Custom Dataset**

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=/content/drive/MyDrive/Dataset/BikeHelmet/data.yaml epochs=10 imgsz=640 batch=16
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # **Output: Prediction based on input**

# %%
# !yolo detect predict model=/content/runs/detect/train6/weights/best.pt source='/content/BikesHelmets99_png_jpg.rf.ba991a75edc25d8cb0e4a0a9d3f02ee3.jpg' save=True
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,608,150 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/BikesHelmets99_png_jpg.rf.ba991a75edc25d8cb0e4a0a9d3f02ee3.jpg: 640x640 4 Without Helmets, 62.7ms
# Speed: 7.7ms preprocess, 62.7ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict model=/content/runs/detect/train6/weights/best.pt source='/content/6b1bdefb532196793dc1c223e1355013.jpg' save=True
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,608,150 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/6b1bdefb532196793dc1c223e1355013.jpg: 448x640 3 Without Helmets, 60.6ms
# Speed: 2.5ms preprocess, 60.6ms inference, 3.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict model=/content/runs/detect/train6/weights/best.pt source='/content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4' save=True
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,608,150 parameters, 0 gradients, 164.8 GFLOPs
#
# video 1/1 (frame 1/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 2 With Helmets, 60.9ms
# video 1/1 (frame 2/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 (no detections), 39.6ms
# video 1/1 (frame 3/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 1 With Helmet, 38.6ms
# video 1/1 (frame 4/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 (no detections), 29.7ms
# video 1/1 (frame 5/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 (no detections), 29.6ms
# video 1/1 (frame 6/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 (no detections), 29.7ms
# video 1/1 (frame 7/192) /content/WhatsApp Video 2025-11-03 at 1.07.27 PM.mp4: 640x384 1 With Helmet, 29.8ms
# ...
